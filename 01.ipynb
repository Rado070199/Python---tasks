# %%
import numpy as np
import matplotlib.pyplot as plt

#Współrzędne punktów
plt.plot([5],[7], "r*")
plt.plot([12],[4], "bo")

plt.axis((0, 15, 0, 10)) #Zakres osi x i y
plt.xticks(np.arange(0, 15 + 1, 1))
plt.yticks(np.arange(0, 10 + 1, 1))
# Out:
# ([<matplotlib.axis.YTick at 0x2205f226d50>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9'),
#   Text(0, 10, '10')])
